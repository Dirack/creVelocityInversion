# %% [markdown]
# ## Inversão do modelo de velocidades
#
# Utilizando o modelo de 3 camadas, v1=1.508, v2=1.690, v3=2.000, abaixo:

# %%
from IPython.display import Image
Image(filename='model.jpg', width=800)

# %% [markdown]
# Obtemos a seção empilhada a partir do processamento sísmico convencional (Análise de  velocidades, correção NMO, etc). A seção empilhada é exibida abaixo:

# %%
from IPython.display import Image
Image(filename='stackedSection.jpg', width=800)

# %% [markdown]
# Fazendo o picking iterativo na seção empilhada, simulamos hipérboles de difração em pontos escolhidos da seção associados a eventos de reflexão

# %%
from IPython.display import Image
Image(filename='diffractionSimulation.jpg', width=800)

# %% [markdown]
# Refazemos a análise de velocidades utilizando a continuação de velocidades (velocity continuation) e a focalização de difrações das difrações simuladas como critério de otimização das velocidades.

# %%
from IPython.display import Image
Image(filename='focusingAnalisysResult.jpg', width=800)

# %% [markdown]
# Este modelo é suavizado antes da inversão de velocidades para estimativa do modelo de velocidades em profundidade

# %%
from IPython.display import Image
Image(filename='vdix.jpg', width=800)

# %% [markdown]
# Por fim, o modelo de velocidades em profundidade é obtido a partir do algoritmo descrito no paper _Time-to-depth conversion and seismic velocity estimation using time-migration velocity_ (Cameron, 2008)

# %%
from IPython.display import Image
Image(filename='velocityInversionResult.jpg', width=800)
